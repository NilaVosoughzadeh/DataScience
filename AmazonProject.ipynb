# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Ecommerce Purchases.txt")

# %%
df.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %%
df["Purchase Price"].mean()
# Out:
# np.float64(50.347302)

# %%
df["Purchase Price"].std()
# Out:
# 29.015836309789048

# %%
df["Purchase Price"].max()
# Out:
# 99.99

# %%
df["Purchase Price"].min()
# Out:
# 0.0

# %%
len(df[df["Language"] == "en"])
# Out:
# 1098

# %%
len(df[df["Job"] == "Lawyer"])
# Out:
# 30

# %%
df["Job"].value_counts()
# Out:
# Job
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Research officer, political party    27
# Designer, jewellery                  27
#                                      ..
# Stage manager                         7
# Actuary                               6
# Editor, film/video                    6
# Information systems manager           5
# Investment analyst                    5
# Name: count, Length: 623, dtype: int64

# %%
df["Job"].unique()
# Out:
# array(['Scientist, product/process development', 'Drilling engineer',
#        'Customer service manager', 'Fine artist', 'Fish farm manager',
#        'Dancer', 'Event organiser', 'Financial manager',
#        'Forensic scientist', 'Development worker, community',
#        'Diagnostic radiographer', 'Surveyor, quantity',
#        'Accountant, chartered public finance', 'Acupuncturist',
#        'Retail manager', 'Therapist, art', 'Designer, jewellery',
#        'Photographer', 'Designer, interior/spatial',
#        'Public relations officer', 'Presenter, broadcasting',
#        'Field seismologist', 'Musician',
#        'Training and development officer', "Barrister's clerk",
#        'Careers adviser', 'Scientist, research (life sciences)',
#        'Recycling officer', 'Fisheries officer', 'Sales executive',
#        'Civil Service fast streamer', 'Theatre stage manager',
#        'Therapist, music', 'Lecturer, further education',
# ...

# %%
df[df["Job"] == "Lawyer"]["Purchase Price"].mean()
# Out:
# np.float64(53.46166666666666)

# %%
df[df["Job"] == "Lawyer"]["Purchase Price"].max()
# Out:
# 97.06

# %%
df[(df["Job"] == "Lawyer") & (df["Purchase Price"] == 97.06)]
# Out:
#                                                 Address    Lot AM or PM  \
# 5452  8651 Joseph Gateway\nSandraborough, ID 48764-6892  70 aF       AM
#
#                                            Browser Info        Company  \
# 5452  Mozilla/5.0 (compatible; MSIE 6.0; Windows NT ...  Ross and Sons
#
#           Credit Card CC Exp Date  CC Security Code    CC Provider  \
# 5452  344498441835254       03/20               990  VISA 13 digit
#
#                   Email     Job   IP Address Language  Purchase Price
# 5452  nwalker@yahoo.com  Lawyer  53.90.42.20       es           97.06

# %%
df["AM or PM"].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
df[df['Lot'] == '90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
df[(df["CC Provider"]=="American Express") & (df["Purchase Price"]>95)]["Purchase Price"].sum()
# Out:
# np.float64(3805.65)

# %%
emails = list(df["Email"])
emails
# Out:
# ['pdunlap@yahoo.com',
#  'anthony41@reed.com',
#  'amymiller@morales-harrison.com',
#  'brent16@olson-robinson.info',
#  'christopherwright@gmail.com',
#  'ynguyen@gmail.com',
#  'olivia04@yahoo.com',
#  'phillip48@parks.info',
#  'kdavis@rasmussen.com',
#  'qcoleman@hunt-huerta.com',
#  'ustewart@hotmail.com',
#  'johnnymiller@coleman.com',
#  'tholt@hotmail.com',
#  'caitlin57@yahoo.com',
#  'aburns@yahoo.com',
#  'amanda39@yahoo.com',
#  'griffincatherine@wilson.com',
#  'stacymitchell@hall.com',
#  'hannah63@yahoo.com',
#  'ruiznicole@gmail.com',
#  'zstephenson@smith.info',
#  'rsmith@hotmail.com',
#  'chambersmichael@gmail.com',
#  'ltaylor@gardner-meadows.com',
#  'james07@yahoo.com',
#  'madison41@mooney.com',
#  'mlogan@gmail.com',
#  'michael35@hotmail.com',
#  'khandeborah@yahoo.com',
#  'stonekaren@yahoo.com',
#  'laurahess@hotmail.com',
#  'ashley12@hotmail.com',
#  'shane21@atkinson.com',
#  'salazarpatricia@yahoo.com',
#  'mdavis@carey-davis.com',
# ...

# %%
domains = []
for email in emails:
  domains.append(email.split("@")[1])

domains_count = {}

for domain in set(domains):
  domains_count[domain] = domains.count(domain)

for i in domains_count:
  if domains_count[i] == 1638 or domains_count[i] == 1616 or domains_count[i] == 1605:
    print(i)
# Out:
# yahoo.com
# hotmail.com
# gmail.com

# %%
data = pd.read_csv("RadioJavan_Top.csv")

# %%
data.head(10)
# Out:
#          artistName           musicName  Radiojavan_play  Radiojavan_likes  \
# 0              Sasy           Gentleman         97011366             92837
# 1    Mohsen Yeganeh    Behet Ghol Midam         82238605             92258
# 2       Behnam Bani      Ashegham Karde         68372476             66724
# 3             Masih  To Ke Nisti Pisham         68357479             93209
# 4             Masih        100 Rishteri         68074878             50030
# 5   Shadmehr Aghili          Door Shodi         67084762             74643
# 6    Hamed Homayoun         Chatre Khis         64675480             76749
# 7             Masih               Darya         64366558             73310
# 8  Masih & Arash Ap           Bia Bazam         59912047             65190
# 9            Ashvan              Sheyda         59474379             66437
#
#        pubdate                                              lyric  \
# 0   Mar 6 2019  هی وقتشه بدی لبِ رو بیبی\nبدو بدو بگیر کمرو هی...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artistName        625 non-null    object
#  1   musicName         625 non-null    object
#  2   Radiojavan_play   625 non-null    int64
#  3   Radiojavan_likes  625 non-null    int64
#  4   pubdate           625 non-null    object
#  5   lyric             625 non-null    object
#  6   musicID           625 non-null    object
#  7   popularity        625 non-null    int64
#  8   danceability      625 non-null    float64
#  9   energy            625 non-null    float64
#  10  key               625 non-null    int64
#  11  loudness          625 non-null    float64
#  12  mode              625 non-null    int64
#  13  speechiness       625 non-null    float64
#  14  acousticness      625 non-null    float64
#  15  instrumentalness  625 non-null    float64
# ...

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df = pd.DataFrame({"A":[1,2,3],
                   "B":[4,np.nan,np.nan],
                   "C":[6,7,np.nan],
                   "D":[9,np.nan,11]})

# %%
df
# Out:
#    A    B    C     D
# 0  1  4.0  6.0   9.0
# 1  2  NaN  7.0   NaN
# 2  3  NaN  NaN  11.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       1 non-null      float64
#  2   C       2 non-null      float64
#  3   D       2 non-null      float64
# dtypes: float64(3), int64(1)
# memory usage: 228.0 bytes

# %%
df.isnull().sum()
# Out:
# A    0
# B    2
# C    1
# D    1
# dtype: int64

# %%
df.dropna()
# Out:
#    A    B    C    D
# 0  1  4.0  6.0  9.0

# %%
df.dropna(axis=1)
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
df #inplace should be True
# Out:
#    A    B    C     D
# 0  1  4.0  6.0   9.0
# 1  2  NaN  7.0   NaN
# 2  3  NaN  NaN  11.0

# %%
df.dropna(thresh=3)
# Out:
#    A    B    C    D
# 0  1  4.0  6.0  9.0

# %%
df.fillna(value=8)
# Out:
#    A    B    C     D
# 0  1  4.0  6.0   9.0
# 1  2  8.0  7.0   8.0
# 2  3  8.0  8.0  11.0

# %%
df["B"].fillna(value=df["B"].mean())
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# Name: B, dtype: float64

# %%
df["B"].fillna(value=df["B"].mean(),inplace=True)
df["C"].fillna(value=df["C"].mean(),inplace=True)
df["D"].fillna(value=df["D"].mean(),inplace=True)
df
# Out:
# <ipython-input-63-acb30fe2148a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["B"].fillna(value=df["B"].mean(),inplace=True)
# <ipython-input-63-acb30fe2148a>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...
